# %%
import matplotlib.pyplot as plt
import numpy as np
losses1= np.load('./losses_e1.npy')

losses = np.load('./losses.npy')

losses = np.concat((losses1,losses))

plt.figure()
plt.plot(losses)
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('RMSE (Train)')
plt.show()
